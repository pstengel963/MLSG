# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import scipy.stats as ss

# %%
# Set-up.
n = 100
np.random.seed(0x5eed)
# Parameters of the mixture components
norm_params = np.array([[5, 1.9],
                        [9, 1.]])
n_components = norm_params.shape[0]
# Weight of each component, in this case all of them are 1/2
weights = np.ones(n_components, dtype=np.float64) / 2.0
# A stream of indices from which to choose the component
mixture_idx = np.random.choice(len(weights), size=n, replace=True, p=weights)
# y is the mixture sample
y = np.fromiter((ss.norm.rvs(*(norm_params[i])) for i in mixture_idx),
                   dtype=np.float64)

# Theoretical PDF plotting -- generate the x and y plotting positions
xs = np.linspace(y.min(), y.max(), 200)
ys = np.zeros_like(xs)

for (l, s), w in zip(norm_params, weights):
    ys += ss.norm.pdf(xs, loc=l, scale=s) * w

# %%
plt.plot(xs, ys)
plt.hist(y, density=True, bins=3)
plt.xlabel("x")
plt.ylabel("f(x)")
plt.show()

# %%
plt.plot(xs, ys)
plt.hist(y, density=True, bins=15)
plt.xlabel("x")
plt.ylabel("f(x)")
plt.show()

# %%
plt.plot(xs, ys)
plt.hist(y, density=True, bins=80)
plt.xlabel("x")
plt.ylabel("f(x)")
plt.show()
